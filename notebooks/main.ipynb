# %%
#choisir option americaine européenne
#utiliser les 3 modeles et voir quel est le meilleur modele 
#etudier marche stable/instable
#utiliser les fonctions dans le src

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.backtester import *
